# %%
import numpy as np
import pandas as pd

from nlp_helper import pipeline
from nlp_helper import preprocess
from nlp_helper import exploration
from nlp_helper import topic_model
from nlp_helper import classification

from importlib import reload

def myReload():
    global pipeline
    global preprocess
    global exploration
    global topic_model
    global classification
    
    pipeline = reload(pipeline)
    preprocess = reload(preprocess)
    exploration = reload(exploration)
    topic_model = reload(topic_model)
    classification = reload(classification)

# %% [markdown]
# ## Deteksi Clickbait

# %%
myReload()

# %%
# %%time
pipeline.runClassification("df_clickbait", fold_num=0, feature_selection=True)
# Out:
# range_used = [0]
# START FEATURE EXTRACTION df_clickbait_fold_0_(1, 1) AT Fri May 26 21:43:45 2023
#
# VOCAB: Original 9339 vs Selected 4724
# TOPIC: Original 2 vs Selected 2
# START CLASSIFICATION df_clickbait_fold_0_(1, 1)
#
# START df_clickbait_fold_0_(1, 1)_A at Fri May 26 21:53:03 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.652 total time=  38.6s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.508 total time=  38.7s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_clickbait", fold_num=1, feature_selection=True)
# Out:
# range_used = [1]
# START FEATURE EXTRACTION df_clickbait_fold_1_(1, 1) AT Sat May 27 01:10:05 2023
#
# VOCAB: Original 9377 vs Selected 4825
# TOPIC: Original 23 vs Selected 23
# START CLASSIFICATION df_clickbait_fold_1_(1, 1)
#
# START df_clickbait_fold_1_(1, 1)_A at Sat May 27 01:19:38 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.637 total time=  39.5s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.504 total time=  40.9s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_clickbait", fold_num=2, feature_selection=True)
# Out:
# range_used = [2]
# START FEATURE EXTRACTION df_clickbait_fold_2_(1, 1) AT Sat May 27 04:37:22 2023
#
# VOCAB: Original 9337 vs Selected 4705
# TOPIC: Original 11 vs Selected 11
# START CLASSIFICATION df_clickbait_fold_2_(1, 1)
#
# START df_clickbait_fold_2_(1, 1)_A at Sat May 27 04:46:50 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.651 total time=  39.9s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.466 total time=  38.7s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_clickbait", fold_num=3, feature_selection=True)
# Out:
# range_used = [3]
# START FEATURE EXTRACTION df_clickbait_fold_3_(1, 1) AT Sat May 27 13:27:48 2023
#
# VOCAB: Original 9310 vs Selected 4781
# TOPIC: Original 12 vs Selected 12
# START CLASSIFICATION df_clickbait_fold_3_(1, 1)
#
# START df_clickbait_fold_3_(1, 1)_A at Sat May 27 13:37:26 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.663 total time=  42.0s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.480 total time=  40.8s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_clickbait", fold_num=4, feature_selection=True)
# Out:
# range_used = [4]
# START FEATURE EXTRACTION df_clickbait_fold_4_(1, 1) AT Sat May 27 16:54:07 2023
#
# VOCAB: Original 9378 vs Selected 4735
# TOPIC: Original 8 vs Selected 8
# START CLASSIFICATION df_clickbait_fold_4_(1, 1)
#
# START df_clickbait_fold_4_(1, 1)_A at Sat May 27 17:03:44 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.590 total time=  40.5s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.498 total time=  39.2s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %% [markdown]
# ## Ulasan Google Play

# %%
myReload()

# %%
# %%time
pipeline.runClassification("df_review", fold_num=0, feature_selection=True)
# Out:
# range_used = [0]
# START FEATURE EXTRACTION df_review_fold_0_(1, 1) AT Sat May 27 21:49:43 2023
#
# VOCAB: Original 5070 vs Selected 2592
# TOPIC: Original 13 vs Selected 13
# START CLASSIFICATION df_review_fold_0_(1, 1)
#
# START df_review_fold_0_(1, 1)_A at Sat May 27 21:53:25 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.686 total time=  11.8s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.726 total time=  12.9s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_review", fold_num=1, feature_selection=True)
# Out:
# range_used = [1]
# START FEATURE EXTRACTION df_review_fold_1_(1, 1) AT Sat May 27 22:49:01 2023
#
# VOCAB: Original 5176 vs Selected 2627
# TOPIC: Original 4 vs Selected 4
# START CLASSIFICATION df_review_fold_1_(1, 1)
#
# START df_review_fold_1_(1, 1)_A at Sat May 27 22:52:46 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.690 total time=  13.4s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.721 total time=  13.9s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_review", fold_num=2, feature_selection=True)
# Out:
# range_used = [2]
# START FEATURE EXTRACTION df_review_fold_2_(1, 1) AT Sat May 27 23:49:17 2023
#
# VOCAB: Original 5147 vs Selected 2580
# TOPIC: Original 10 vs Selected 10
# START CLASSIFICATION df_review_fold_2_(1, 1)
#
# START df_review_fold_2_(1, 1)_A at Sat May 27 23:53:01 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.698 total time=  13.8s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.733 total time=  14.2s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_review", fold_num=3, feature_selection=True)
# Out:
# range_used = [3]
# START FEATURE EXTRACTION df_review_fold_3_(1, 1) AT Sun May 28 00:48:13 2023
#
# VOCAB: Original 5165 vs Selected 2625
# TOPIC: Original 2 vs Selected 2
# START CLASSIFICATION df_review_fold_3_(1, 1)
#
# START df_review_fold_3_(1, 1)_A at Sun May 28 00:51:59 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.680 total time=  13.5s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.729 total time=  13.4s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_review", fold_num=4, feature_selection=True)
# Out:
# range_used = [4]
# START FEATURE EXTRACTION df_review_fold_4_(1, 1) AT Sun May 28 01:48:41 2023
#
# VOCAB: Original 5086 vs Selected 2567
# TOPIC: Original 19 vs Selected 19
# START CLASSIFICATION df_review_fold_4_(1, 1)
#
# START df_review_fold_4_(1, 1)_A at Sun May 28 01:52:23 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.675 total time=  13.9s
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.699 total time=  12.3s
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %% [markdown]
# ## Kategorisasi Berita

# %%
myReload()

# %%
# %%time
pipeline.runClassification("df_categories", fold_num=0, feature_selection=True)
# Out:
# range_used = [0]
# START FEATURE EXTRACTION df_categories_fold_0_(1, 1) AT Sun May 28 02:47:55 2023
#
# VOCAB: Original 31462 vs Selected 16836
# TOPIC: Original 18 vs Selected 18
# START CLASSIFICATION df_categories_fold_0_(1, 1)
#
# START df_categories_fold_0_(1, 1)_A at Sun May 28 03:24:20 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.837 total time= 2.9min
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.855 total time= 3.0min
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_categories", fold_num=1, feature_selection=True)
# Out:
# range_used = [1]
# START FEATURE EXTRACTION df_categories_fold_1_(1, 1) AT Tue May 30 04:41:54 2023
#
# VOCAB: Original 31636 vs Selected 16760
# TOPIC: Original 43 vs Selected 43
# START CLASSIFICATION df_categories_fold_1_(1, 1)
#
# START df_categories_fold_1_(1, 1)_A at Tue May 30 05:18:25 2023
#
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 1/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.819 total time= 3.0min
# [CV 2/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# [CV 2/5; 1/3] END l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga;, score=0.844 total time= 3.2min
# [CV 3/5; 1/3] START l1_ratio=0.25, multi_class=multinomial, penalty=elasticnet, random_state=None, solver=saga
# ...

# %%
# %%time
pipeline.runClassification("df_categories", fold_num=2, feature_selection=True)
# Out:
# range_used = [2]
# START FEATURE EXTRACTION df_categories_fold_2_(1, 1) AT Tue May 30 06:55:37 2023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Documents\00 IPB\Tugas Akhir\Coding\nlp_helper\pipeline.py in runClassification(save_name, fold_num, n_splits, ngram_range, feature_selection, random_state)
#     185         print(f"START FEATURE EXTRACTION {save_name_fold_ngram} AT {custom_timer.time_now(asc=True)}\n")
#     186         # TF-IDF
# --> 187         tfidf_model = classification.feature_extraction_fit(X_class_train, y_train, ngram_range=ngram_range, feature_selection=feature_selection, save_name=save_name_fold)
#     188         A_train, B_train, C_train = classification.feature_extraction_transform(tfidf_model, X_class_train, topics_df_train, y_train, feature_selection=feature_selection)
# ...

# %%
# %%time
pipeline.runClassification("df_categories", fold_num=3, feature_selection=True)
# Out:
# range_used = [3]
# START FEATURE EXTRACTION df_categories_fold_3_(1, 1) AT Tue May 30 07:28:02 2023
# KeyboardInterrupt

# %%
# %%time
pipeline.runClassification("df_categories", fold_num=4, feature_selection=True)
# Out:
# range_used = [4]
# START FEATURE EXTRACTION df_categories_fold_4_(1, 1) AT Tue May 30 07:33:37 2023
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Documents\00 IPB\Tugas Akhir\Coding\nlp_helper\pipeline.py in runClassification(save_name, fold_num, n_splits, ngram_range, feature_selection, random_state)
#     185         print(f"START FEATURE EXTRACTION {save_name_fold_ngram} AT {custom_timer.time_now(asc=True)}\n")
#     186         # TF-IDF
# --> 187         tfidf_model = classification.feature_extraction_fit(X_class_train, y_train, ngram_range=ngram_range, feature_selection=feature_selection, save_name=save_name_fold)
#     188         A_train, B_train, C_train = classification.feature_extraction_transform(tfidf_model, X_class_train, topics_df_train, y_train, feature_selection=feature_selection)
# ...
